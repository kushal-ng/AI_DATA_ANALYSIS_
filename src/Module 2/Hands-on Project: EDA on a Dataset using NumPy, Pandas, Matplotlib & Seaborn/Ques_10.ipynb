# %%
# Step 1: Set Up the Environment
# Objective: Ensure you have the right tools and packages installed.

# 1. Install the required libraries.
# 2. Verify the installation by importing the libraries in a Python script or Jupyter notebook





# Step 2: Load & Explore the Dataset
# Objective: Load data into a pandas DataFrame and obtain a basic understanding of its structure.

# 3. Load a CSV file into a DataFrame.
# 4. Display the first few records to understand the structure.
# 5. Get a summary of the dataset.

import pandas as pd

# Load a CSV file into a DataFrame
df = pd.read_csv('dataset.csv')  # Replace with your file path

# Display the first few records to understand the structure
print(df.head())

# Get a summary of the dataset
print(df.info())
print(df.describe())




# Step 3: Perform NumPy Operations
# Objective: Utilize NumPy for basic numerical operations and array manipulations.

# 6. Convert a DataFrame column to a NumPy array and perform array operations like mean and sum.
# 7. Create a NumPy array and calculate the variance and standard deviation.
# 8. Use NumPy to filter based on conditions.


import numpy as np

# Convert a DataFrame column to a NumPy array and perform array operations like mean and sum
column_data = df['column_name'].to_numpy()  # Replace 'column_name' with your column
mean_value = np.mean(column_data)
sum_value = np.sum(column_data)

# Create a NumPy array and calculate the variance and standard deviation
data_array = np.array([1, 2, 3, 4, 5])
variance = np.var(data_array)
std_dev = np.std(data_array)

# Use NumPy to filter based on conditions
filtered_data = df[df['column_name'] > 50]  # Replace 'column_name' with your column






# Step 4: Data Manipulation with Pandas
# Objective: Use Pandas to clean and manipulate dataset for analysis.

# 9. Handle missing data by filling or dropping.
# 10. Create new columns or modify existing ones.
# 11. Use groupby to aggregate data.



# Handle missing data by filling or dropping
df.fillna(df.median(), inplace=True)  # Filling missing values with the median

# Create new columns or modify existing ones
df['new_column'] = df['column_name'] * 2  # Example of modifying or adding a new column

# Use groupby to aggregate data
grouped_data = df.groupby('category_column')['numerical_column'].mean()  # Replace with your columns
print(grouped_data)




# Step 5: Data Visualization with Matplotlib & Seaborn
# Objective: Visualize the data to identify patterns, trends, and insights.

# 12. Use Matplotlib to create a basic plot.
# 13. Create a histogram using Seaborn.
# 14. Plot a box plot for a clear view of data distribution.

import matplotlib.pyplot as plt
import seaborn as sns

# Use Matplotlib to create a basic plot
plt.plot(df['column_name'])  # Replace 'column_name' with your data
plt.title('Basic Line Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# Create a histogram using Seaborn
sns.histplot(df['column_name'], kde=True)  # Replace 'column_name' with your data
plt.title('Histogram with KDE')
plt.show()

# Plot a box plot for a clear view of data distribution
sns.boxplot(x='category_column', y='numerical_column', data=df)  # Replace with your columns
plt.title('Box Plot')
plt.show()
